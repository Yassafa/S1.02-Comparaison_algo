# %%
from time import time
from random import randint
from santa_claus import *
# Out:
# True
# ['Marseille', 'Paris', 'Lille', 'Lyon']

# %%
# Question 4
tab_villes = ["Paris",2.33,48.86, "Lyon",4.85,45.75,"Marseille", 5.40,43.30, "Lille",3.06,50.63,"Strasbourg",7.75,48.57,"Rennes",-1.66,48.11,"Clermont-Ferrand",3.08,45.77, "Bordeaux", -0.57, 44.83]
tic = time()
i = 0
while i < 1000:
    long_tour(tab_villes,["Paris", "Lyon", "Marseille", "Lille"])
    i += 1
tac = time()
print("Durée d'execution de long_tour :",(tac-tic)*1000)

dico_villes = {'Paris': {'Lyon': 394.5056834297657, 'Marseille': 661.8616554466852, 'Lille': 203.67224282542662}, 'Lyon': {'Paris': 394.5056834297657, 'Marseille': 275.87965367431525, 'Lille': 558.5472363339435}, 'Marseille': { 'Paris': 661.8616554466852, 'Lyon': 275.87965367431525, 'Lille': 834.0220261600157}, 'Lille': {'Paris': 203.67224282542662, 'Lyon': 558.5472363339435, 'Marseille': 834.0220261600157}}
tic = time()
i = 0
while i < 1000:
    tour_length(["Paris","Lyon","Marseille","Lille"],dico_villes)
    i += 1
tac = time()
print("Durée d'execution de tour_length :",(tac-tic)*1000)
# Out:
# Durée d'execution de long_tour : 128.9999485015869
# Durée d'execution de tour_length : 5.00035285949707

# %%
# Question 13
tab = lecture_villes("africa.csv")
dico_villes = dictionary_cities(tab)

# %%
tic = time()
i = 0
while i < 10:
    ville = tab[randint(0,len(tab)-1)]
    tour_from_closest_city(ville,dico_villes)
    i += 1
tac = time()
print("Durée d'execution du premier algorithme :",(tac-tic)*1000)
# Out:
# Durée d'execution du premier algorithme : 17.000198364257812

# %%
tic = time()
i = 0
while i < 10:
    best_tour_from_closest_city(dico_villes)
    i += 1
tac = time()
print("Durée d'execution du deuxième algorithme :",(tac-tic)*1000)
# Out:
# Durée d'execution du deuxième algorithme : 952.9998302459717

# %%
tic = time()
i = 0
while i < 10:
    best_obtained_with_inversions(tab,dico_villes)
    i += 1
tac = time()
print("Durée d'execution du troisième algorithme :",(tac-tic)*1000)
